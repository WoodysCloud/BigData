# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 
root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

editbox1 = tk.Entry(width=4)
editbox1.place(x=140, y=20)

root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

root.mainloop()    # 윈도우 표시하기
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-f2c93a182f9e> in <module>
#      11 editbox1.place(x=140, y=60)
#      12
# ---> 13 root.mainloop()    # 윈도우 표시하기
#
# /opt/anaconda3/lib/python3.8/tkinter/__init__.py in mainloop(self, n)
#    1427     def mainloop(self, n=0):
#    1428         """Call the mainloop of Tk."""
# -> 1429         self.tk.mainloop(n)
#    1430
#    1431     def quit(self):
#
# KeyboardInterrupt:

# %%
import tkinter as tk
for f in tk.Tk().call("font", "families"):
    print(f)
# Out:
# Academy Engraved LET
# Al Bayan
# Al Nile
# Al Tarikh
# American Typewriter
# Andale Mono
# Apple Braille
# Apple Chancery
# Apple Color Emoji
# Apple SD Gothic Neo
# Apple Symbols
# AppleGothic
# AppleMyungjo
# Arial
# Arial Black
# Arial Hebrew
# Arial Hebrew Scholar
# Arial Narrow
# Arial Rounded MT Bold
# Arial Unicode MS
# Artifakt Element
# Avenir
# Avenir Next
# Avenir Next Condensed
# Ayuthaya
# Baghdad
# Bangla MN
# Bangla Sangam MN
# Baskerville
# Beirut
# Big Caslon
# Binggrae Samanco
# Bodoni 72
# Bodoni 72 Oldstyle
# Bodoni 72 Smallcaps
# Bodoni Ornaments
# Bradley Hand
# Brush Script MT
# Chalkboard
# Chalkboard SE
# Chalkduster
# Charter
# Cochin
# Comic Sans MS
# Copperplate
# Corsiva Hebrew
# Courier
# Courier New
# Damascus
# DecoType Naskh
# Devanagari MT
# Devanagari Sangam MN
# Didot
# DIN Alternate
# DIN Condensed
# Diwan Kufi
# Diwan Thuluth
# Euphemia UCAS
# Farah
# Farisi
# Futura
# Galvji
# GB18030 Bitmap
# Geeza Pro
# Geneva
# Georgia
# Gill Sans
# ...

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

button1 = tk.Button(root, text="확인", font=("Helvetica", 14))
button1.place(x=220, y=60)

root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk

root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

button1 = tk.Button(root, text="확인", font=("Helvetica", 14), command=ButtonClick)    # click: 클릭하면 함수 실행
button1.place(x=220, y=60)

root.mainloop()    # 윈도우 표시하기
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-b6aa3d78fdd9> in <module>
#      11 editbox1.place(x=140, y=60)
#      12
# ---> 13 button1 = tk.Button(root, text="확인", font=("Helvetica", 14), command=ButtonClick)    # click: 클릭하면 함수 실행
#      14 button1.place(x=220, y=60)
#      15
#
# NameError: name 'ButtonClick' is not defined

# %%
import tkinter as tk
import tkinter.messagebox as tmsg

# 버튼이 클릭되었을 때의 처리
def ButtonClick():
    # 텍스트 입력칸에 입력된 문자열을 취득
    b = editbox1.get()
    # 메세지로서 표시한다
    tmsg.showinfo("입력된 텍스트", b)

# 메인 프로그램
# 윈도우를 만든다
root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

# 라벨을 만든다
label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

# 텍스트 박스를 만든다
editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

# 버튼을 만든다
button1 = tk.Button(root, text="확인", font=("Helvetica", 14), command=ButtonClick)    # click: 클릭하면 함수 실행
button1.place(x=220, y=60)

# 윈도우를 표시한다
root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk
import tkinter.messagebox as tmsg
import random

# 버튼이 클릭되었을 때의 처리
def ButtonClick():
    # 텍스트 입력칸에 입력된 문자열을 취득
    b = editbox1.get()
    # 메세지로서 표시한다
    tmsg.showinfo("입력된 텍스트", b)
    
    isok = False
    if len(b) != 4:
        tmsg.showerror("오류", "4자릿수의 숫자를 입력하세요")
    else:
        numberok = True
        for i in range(4):
            if (b[i] < "0") or (b[i] > "9"):
                tmsg.showerror("오류", "숫자가 아닙니다")
                numberok = False
                break
        if numberok:
            isok = True
            
    if isok:
        # 4자릿수의 숫자였을 때
        # 히트 판정
        hit = 0
        for i in range(4):
            if a[i] == int(b[i]):
                hit = hit + 1
        
        # 블로 판정
        blow = 0
        for j in range(4):
            for i in range(4):
                if (int(b[j]) == a[i]) and (a[i] != int(b[i])) and (a[j] != int(b[j])):
                    blow = blow + 1
                    break
        
        # 히트가 4라면 맞춰서 종료
        if hit == 4:
            tmsg.showinfo("맞췄다", "축하합니다. 맞췄습니다")
            
            # 종료
            root.destroy()
        else:
            # 히트수, 블로수 표시
            tmsg.showinfo("힌트", "히트 " + str(hit) + "/" + "블로 " + str(blow))
            
    

# 메인 프로그램
# 처음에 랜덤인 4개의 숫자를 작성해 둔다
a = [random.randint(0, 9),
    random.randint(0, 9),
    random.randint(0, 9),
    random.randint(0, 9)]


# 윈도우를 만든다
root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

# 라벨을 만든다
label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

# 텍스트 박스를 만든다
editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

# 버튼을 만든다
button1 = tk.Button(root, text="확인", font=("Helvetica", 14), command=ButtonClick)    # click: 클릭하면 함수 실행
button1.place(x=220, y=60)

# 윈도우를 표시한다
root.mainloop()    # 윈도우 표시하기

# %%
import tkinter as tk
import tkinter.messagebox as tmsg
import random


# 처음에 랜덤인 4개의 숫자를 작성해 둔다
a = [random.randint(0, 9),
    random.randint(0, 9),
    random.randint(0, 9),
    random.randint(0, 9)]

# 버튼이 클릭되었을 때의 처리
def ButtonClick():
    # 텍스트 입력칸에 입력된 문자열을 취득
    b = editbox1.get()
    # 메세지로서 표시한다
#     tmsg.showinfo("입력된 텍스트", b)
    
    isok = False
    if len(b) != 4:
        tmsg.showerror("오류", "4자릿수의 숫자를 입력하세요")
    else:
        numberok = True
        for i in range(4):
            if (b[i] < "0") or (b[i] > "9"):
                tmsg.showerror("오류", "숫자가 아닙니다")
                numberok = False
                break
        if numberok:
            isok = True
            
    if isok:
        # 4자릿수의 숫자였을 때
        # 히트 판정
        hit = 0
        for i in range(4):
            if a[i] == int(b[i]):
                hit = hit + 1
        
        # 블로 판정
        blow = 0
        for j in range(4):
            for i in range(4):
                if (int(b[j]) == a[i]) and (a[i] != int(b[i])) and (a[j] != int(b[j])):
                    blow = blow + 1
                    break
        
        # 히트가 4라면 맞춰서 종료
        if hit == 4:
            tmsg.showinfo("맞췄다", "축하합니다. 맞췄습니다")
            
            # 종료
            root.destroy()
        else:
            # 히트수, 블로수 표시
            tmsg.showinfo("힌트", "히트 " + str(hit) + "/" + "블로 " + str(blow))
            
    

# 메인 프로그램
# 윈도우를 만든다
root = tk.Tk()    # 윈도우 만들기
root.geometry("400x150")    # 윈도우 크기
root.title("수 맞추기 게임")    # 윈도우 제목 

# 라벨을 만든다
label1 = tk.Label(root, text="숫자를 입력하세요")    # label1의 텍스트
label1.place(x=20, y=20)    # label1의 위치(좌표)

# 텍스트 박스를 만든다
editbox1 = tk.Entry(width=4, font=("Helvetica", 28))
editbox1.place(x=140, y=60)

# 버튼을 만든다
button1 = tk.Button(root, text="확인", font=("Helvetica", 14), command=ButtonClick)    # click: 클릭하면 함수 실행
button1.place(x=220, y=60)

# 윈도우를 표시한다
root.mainloop()    # 윈도우 표시하기
